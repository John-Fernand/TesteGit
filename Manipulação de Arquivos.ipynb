# %% [markdown]
# <a href="https://colab.research.google.com/github/John-Fernand/TesteGit/blob/main/Manipula%C3%A7%C3%A3o%20de%20Arquivos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Escreva um programa que receba do usuário os valores de um conjunto de características de um personagem inventado por você.
# Leia os valores e grave um arquivo para posterior manipulação.
# Escolha o formato de gravação.
#
# O arquivo não precisa ser alterado, apenas sobreescrito.
# Crie uma função para ler e apresentar (print) os dados gravados.
# ---

# %%
import json
while True:
  try:
    nome = str(input("Digite um nome."))
    break
  except ValueError:
    print("Valor inválido, digite uma string.")
while True:
  try:
    altura = float(input("Digite a altura."))
    altura = round(altura, 2)
    break
  except ValueError:
    print("Valor inválido, digite um float.")
while True:
  try:
    nivel = int(input("Digite um nível."))
    break
  except ValueError:
    print("Valor inválido, digite um inteiro.")

dados = {
    'Nome': nome,
    'Altura': altura,
    'Nível': nivel,
}
arquivo = open("dados.json",  "w")
json.dump(dados, arquivo)
arquivo.close()
arquivo = open("dados.json", "r")
dados = json.load(arquivo)
arquivo.close()
print(dados)
# Out:
# Digite um nome.Alisson
# Digite a altura.1.75
# Digite um nível.12
# {'Nome': 'Alisson', 'Altura': 1.75, 'Nível': 12}

# %% [markdown]
# Gere uma lista com 20 números aleatórios e, para cada valor, calcule o resultado da multiplicação por 2 e por 10. Salve os dados em TXT, JSON, e CSV contendo três campos: valor original, valor *2, valor *10.

# %%
import json
import random

números = []
i = 0
for i in range(20):
  número = random.randint(0, 10000)
  número2 = número*2
  número10 = número*10
  dados = {'Número': número, 'Número vezes 2': número2, 'Número vezes 10': número10}
  números.append(dados)
for dados in números:
  print(dados)
# Out:
# {'Número': 4684, 'Número vezes 2': 9368, 'Número vezes 10': 46840}
# {'Número': 4646, 'Número vezes 2': 9292, 'Número vezes 10': 46460}
# {'Número': 5574, 'Número vezes 2': 11148, 'Número vezes 10': 55740}
# {'Número': 9999, 'Número vezes 2': 19998, 'Número vezes 10': 99990}
# {'Número': 5120, 'Número vezes 2': 10240, 'Número vezes 10': 51200}
# {'Número': 956, 'Número vezes 2': 1912, 'Número vezes 10': 9560}
# {'Número': 6116, 'Número vezes 2': 12232, 'Número vezes 10': 61160}
# {'Número': 439, 'Número vezes 2': 878, 'Número vezes 10': 4390}
# {'Número': 7744, 'Número vezes 2': 15488, 'Número vezes 10': 77440}
# {'Número': 5588, 'Número vezes 2': 11176, 'Número vezes 10': 55880}
# {'Número': 6964, 'Número vezes 2': 13928, 'Número vezes 10': 69640}
# {'Número': 3621, 'Número vezes 2': 7242, 'Número vezes 10': 36210}
# {'Número': 2206, 'Número vezes 2': 4412, 'Número vezes 10': 22060}
# {'Número': 5609, 'Número vezes 2': 11218, 'Número vezes 10': 56090}
# {'Número': 9065, 'Número vezes 2': 18130, 'Número vezes 10': 90650}
# {'Número': 3824, 'Número vezes 2': 7648, 'Número vezes 10': 38240}
# {'Número': 8334, 'Número vezes 2': 16668, 'Número vezes 10': 83340}
# {'Número': 8708, 'Número vezes 2': 17416, 'Número vezes 10': 87080}
# {'Número': 7907, 'Número vezes 2': 15814, 'Número vezes 10': 79070}
# {'Número': 31, 'Número vezes 2': 62, 'Número vezes 10': 310}
