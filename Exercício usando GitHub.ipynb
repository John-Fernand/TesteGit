# %% [markdown]
# <a href="https://colab.research.google.com/github/John-Fernand/TesteGit/blob/main/Exerc%C3%ADcio%20usando%20GitHub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# !git config --global user.name "John-Fernand"
# !git config --global user.email "250756239+John-Fernand@users.noreply.github.com"
# !git config --global init.defaultBranch main
# !git config --global --list
# Out:
# git version 2.34.1
# user.name=John-Fernand
# user.email=250756239+John-Fernand@users.noreply.github.com
# init.defaultbranch=main

# %%
nota1 = 2
nota2 = 4
nota3 = 3
médianotas = (nota1+nota2+nota3)/3
print(nota1)
print(nota2)
print(nota3)
print(médianotas)
# Out:
# 2
# 4
# 3
# 3.0
