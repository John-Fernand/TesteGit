# %% [markdown]
# <a href="https://colab.research.google.com/github/John-Fernand/TesteGit/blob/main/Usando%20Orienta%C3%A7%C3%A3o%20a%20Objetos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Calculadora:
  continuar = True
  while continuar != False:
    escolha = input("Escolha a operação.\n 1 para adição, 2 para subtração, 3 para multiplicação, 4 para divisão, 5 para exponenciação, 6 para raiz quadrada e 7 para parar o programa.")
    continuarinserção = True
    escolha case:
      case 1:
        while continuarinserção == True:

      case 2:

      case 3:

      case 4:

      case 5:

      case 6:

      case 7:
        continuar = False

# %%
n = int(input("Digite um número "))
p = (n + (n/n) )/2.
print(p*p)
b = p
raizexata = sqrt(n)
while p-raizexata >=0.0001:
    p = (b + (n/b) )/2.
    print(p)
    b = p
print(p)
print(raizexata)
