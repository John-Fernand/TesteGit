# %% [markdown]
# <a href="https://colab.research.google.com/github/John-Fernand/TesteGit/blob/main/EI1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def lista_estudantes():
  lestudantes.append(id)
  id += 1
id = 1
lestudantes = []
estudantes = int(input("Quantos estudantes?"))
while len(lestudantes) <= estudantes:
  lestudantes.append(id)
  id += 1
while
nota = int(input("Qual é a nota do aluno"))
# Out:
# Quantos estudantes?4
# [1, 2, 3, 4, 5]

# %%
def lista_estudantes(id):
  lestudantes.append(id)
  id += 1
  return id
id = 1
lestudantes = []
estudantes = int(input("Quantos estudantes?"))
while len(lestudantes) < estudantes:
  id = lista_estudantes(id)
print(lestudantes)
nota = int(input("Qual é a nota do aluno"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3467/2657315981.py in <cell line: 0>()
#       5 id = 1
#       6 lestudantes = []
# ----> 7 estudantes = int(input("Quantos estudantes?"))
#       8 while len(lestudantes) < estudantes:
#       9   id = lista_estudantes(id)
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
def adicionar_notas():
  nota = int(input("Qual é a nota do aluno"))
  lnotas.append(nota)
  return lnotas
lnotas = []
estudantes = int(input("Quantos estudantes?"))
while estudantes > len(lnotas):
  lnotas = adicionar_notas()
print(lnotas)
for i in range(lnotas)
# Out:
# Quantos estudantes?10
# Qual é a nota do aluno10
# Qual é a nota do aluno10
# Qual é a nota do aluno10
# Qual é a nota do aluno1
# Qual é a nota do aluno2
# Qual é a nota do aluno3
# Qual é a nota do aluno4
# Qual é a nota do aluno5
# Qual é a nota do aluno6
# Qual é a nota do aluno7
# [10, 10, 10, 1, 2, 3, 4, 5, 6, 7]
