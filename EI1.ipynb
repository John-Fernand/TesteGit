# %% [markdown]
# <a href="https://colab.research.google.com/github/John-Fernand/TesteGit/blob/main/EI1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def adicionar_notas():
  nota = int(input("Qual é a nota do aluno"))
  lnotas.append(nota)
  return lnotas
def calcular_menor_nota(lnotas):
  menor_nota = lnotas[0]
  for i in lnotas:
    if i < menor_nota:
      menor_nota = i
  return menor_nota
def calcular_maior_nota(lnotas):
  maior_nota = lnotas[0]
  for i in lnotas:
    if i > maior_nota:
      maior_nota = i
  return maior_nota
def calcular_média(lnotas):
  média_nota = 0
  for i in lnotas:
    média_nota += i
  média_nota = média_nota / len(lnotas)
  return média_nota
def calcular_aprovados(lnotas):
  aprovados = 0
  for i in lnotas:
    if i >= 6:
      aprovados += 1
  return aprovados
def calcular_reprovados(estudantes, aprovados):
  reprovados = estudantes - aprovados
  return reprovados

lnotas = []
estudantes = int(input("Quantos estudantes?"))
while estudantes > len(lnotas):
  lnotas = adicionar_notas()
print(lnotas)
menor_nota = calcular_menor_nota(lnotas)
maior_nota = calcular_maior_nota(lnotas)
média_nota = calcular_média(lnotas)
aprovados = calcular_aprovados(lnotas)
reprovados = calcular_reprovados(estudantes, aprovados)
print(f"A menor nota é {menor_nota}")
print(f"A maior nota é {maior_nota}")
print(f"A média das notas é {média_nota}")
print(f"A quantidade de aprovados é {aprovados}")
print(f"A quantidade de reprovados é {reprovados}")
# Out:
# Quantos estudantes?3
# Qual é a nota do aluno9
# Qual é a nota do aluno7
# Qual é a nota do aluno5
# [9, 7, 5]
# A menor nota é 5
# A maior nota é 9
# A média das notas é 7.0
# A quantidade de aprovados é 2
# A quantidade de reprovados é 1

# %%
def inserir_produto():
  código_produto = int(input("Insira o código do produto "))
  nome_produto = (input("Insira o nome do produto "))
  preço_produto = float(input("Insira o preço do produto "))
  quantidade_produto = int(input("Insira a quantidade do estoque "))
  produto = {'Código': código_produto , "Nome": nome_produto, "Preço": preço_produto, "Quantidade em estoque": quantidade_produto}
  return produto
def consultar_produto(produtos):
  código_desejado = int(input("Diga o código do produto que deseja buscar. "))
  for i in produtos:
    if i["Código"] == código_desejado:
      print(i)
def calcular_valor_estoque(produtos):
  valor_total = 0
  for i in produtos:
    if i["Quantidade em estoque"] > 0:
      valor_total = valor_total + (i["Preço"] * i["Quantidade em estoque"])
  return valor_total
def calcular_maior_valor(produtos):
  maior_valor = 0
  for i in produtos:
    if i["Preço"] > maior_valor:
      maior_valor = i["Preço"]
      produto_maior_valor = i["Nome"]
  print(f"O maior valor unitário é {maior_valor} e é o {produto_maior_valor} ")



continuar_inserir = True
produtos = []
while continuar_inserir == True:
  produtos.append(inserir_produto())
  continuar_inserir = bool(input("Continuar a inserir produtos.(Para parar de inserir, não digite nada.) "))
print(produtos)
consultar_produto(produtos)
valor_total = calcular_valor_estoque(produtos)
print(f"O valor total do estoque é de {valor_total} ")
calcular_maior_valor(produtos)
# Out:
# Insira o código do produto 2
# Insira o nome do produto blusa
# Insira o preço do produto 50
# Insira a quantidade do estoque 10
# Continuar a inserir produtos.(Para parar de inserir, não digite nada.)
# [{'Código': 2, 'Nome': 'blusa', 'Preço': 50.0, 'Quantidade em estoque': 10}]
# Diga o código do produto que deseja buscar. 2
# {'Código': 2, 'Nome': 'blusa', 'Preço': 50.0, 'Quantidade em estoque': 10}
# O valor total do estoque é de 500.0
# O maior valor unitário é 50.0 e é o blusa

# %%
def Adquirir_Valores():
  continuar = 1
  lista_números = []
  while continuar != 0:
    número = float(input("Digite um número(digite 0 caso deseje parar). "))
    if número != 0:
      lista_números.append(número)
    else:
      continuar = 0
  return lista_números
def Quantidade_Valores(lista_números):
  print(f"A quantidade de valores são {len(lista_números)}. ")
def Média_Valores(lista_números):
  média = 0
  for i in lista_números:
    média = média + i
  média = média / len(lista_números)
  print(f"A média dos valores é {média}. ")
def Mediana_Valores(lista_números):
  if len(lista_números) % 2 == 1
    mediana = (len(lista_números) + 1)/2
    print(f"A mediana da lista é: {mediana}. ")
  else
    mediana = (len(lista_números) + len(lista_números) + 1)/2
    print(f"A mediana da lista é: {mediana}. ")
def

lista_números = Adquirir_Valores
Quantidade_Valores(lista_números)
# Out:
#   File "/tmp/ipykernel_2543/1113051694.py", line 20
#     lista_números = Adquirir_Valores
#     ^
# IndentationError: expected an indented block after function definition on line 19
